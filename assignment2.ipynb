# %%
#Tugas No. 1
angka1 = 1
angka1 += 1
angka1 += 1
angka1 += 1
angka1 += 1
print(angka1)
# Out:
# 5

# %%
#Tugas No. 2
angka1 = 5
angka1 -= 1
angka1 -= 1
angka1 -= 1
angka1 -= 1
print(angka1)
# Out:
# 1

# %%
#Tugas No. 3
num1 = input("Angka pertama = ")
num2 = input("Angka kedua = ")
num3 = input("Angka ketiga= ")
num4 = input("Angka keempat = ")
print("angka pertama lebih besar dari angka ketiga =",num1 > num3)
print("angka kedua lebih kecil daripada angka keempat =",num2 < num4)
# Out:
# Angka pertama = 1
# Angka kedua = 2
# Angka ketiga= 3
# Angka keempat = 4
# angka pertama lebih besar dari angka ketiga = False
# angka kedua lebih kecil daripada angka keempat = True

# %%
#Tugas No. 4
num1 = input("Masukkan bilangan bulat pertama = ")
num2 = input("Masukkan bilangan bulat kedua = ")
print(int(num1)**int(num2))
# Out:
# Masukkan bilangan bulat pertama = 2
# Masukkan bilangan bulat kedua = 3
# 8

# %%
#Tugas No. 5
num1 = int(input("Masukkan bilangan bulat = "))

print("Angka adalah genap =", (num1 % 2 == 0))
print("Angka adalah ganjil =", (num1 % 2 == 1))
# Out:
# Masukkan bilangan bulat = 2
# Angka adalah genap = True
# Angka adalah ganjil = False
