# %%
import numpy as np
data = [2,4,6,8,10]

q1 = np.percentile(data, 25) # 18
q2 = np.percentile(data, 50)  # 35
q3 = np.percentile(data, 75)

print(q1)
print(q2)
print(q3)
# Out:
# 4.0
# 6.0
# 8.0

# %%
#No. 1
import io
import pandas as pd

url = ("https://raw.githubusercontent.com/gemara/data_analyst/main/Data-Penindakan-Pelanggaran-Lalu-Lintas.csv")
lalin = pd.read_csv(url)
lalin
# Out:
#        bulan                   wilayah  bap_tilang  stop_operasi  bap_polisi  \
# 0    Januari             Bidang Dalops          44           139           0
# 1    Januari    Sudinhub Jakarta Pusat          47             2          52
# 2    Januari    Sudinhub Jakarta Utara         166            27           0
# 3    Januari  Sudinhub Jakarta Selatan          44             1           0
# 4    Januari    Sudinhub Jakarta Barat         184            70           0
# 5    Januari    Sudinhub Jakarta Timur         191           141           0
# 6   Februari             Bidang Dalops          37           143           0
# 7   Februari    Sudinhub Jakarta Pusat          48             7          42
# 8   Februari    Sudinhub Jakarta Utara         251            27          31
# 9   Februari  Sudinhub Jakarta Selatan         129            12           0
# 10  Februari    Sudinhub Jakarta Barat         229            60           0
# ...

# %%
#Kategoris
kategoris = lalin.iloc[0:, 0:2]
kategoris
# Out:
#        bulan                   wilayah
# 0    Januari             Bidang Dalops
# 1    Januari    Sudinhub Jakarta Pusat
# 2    Januari    Sudinhub Jakarta Utara
# 3    Januari  Sudinhub Jakarta Selatan
# 4    Januari    Sudinhub Jakarta Barat
# 5    Januari    Sudinhub Jakarta Timur
# 6   Februari             Bidang Dalops
# 7   Februari    Sudinhub Jakarta Pusat
# 8   Februari    Sudinhub Jakarta Utara
# 9   Februari  Sudinhub Jakarta Selatan
# 10  Februari    Sudinhub Jakarta Barat
# 11  Februari    Sudinhub Jakarta Timur
# 12     Maret             Bidang Dalops
# 13     Maret    Sudinhub Jakarta Pusat
# 14     Maret    Sudinhub Jakarta Utara
# 15     Maret  Sudinhub Jakarta Selatan
# 16     Maret    Sudinhub Jakarta Barat
# 17     Maret    Sudinhub Jakarta Timur
# 18     April             Bidang Dalops
# 19     April    Sudinhub Jakarta Pusat
# 20     April    Sudinhub Jakarta Utara
# 21     April  Sudinhub Jakarta Selatan
# 22     April    Sudinhub Jakarta Barat
# ...

# %%
#Numeric
numeric = lalin.iloc[0:, 2:]
numeric
# Out:
#     bap_tilang  stop_operasi  bap_polisi  stop_operasi_polisi  penderekan  \
# 0           44           139           0                    0          73
# 1           47             2          52                    0         184
# 2          166            27           0                    0         174
# 3           44             1           0                    0          61
# 4          184            70           0                    0         202
# 5          191           141           0                    0         137
# 6           37           143           0                    0          95
# 7           48             7          42                    0         175
# 8          251            27          31                    0         255
# 9          129            12           0                    0         155
# 10         229            60           0                    0         245
# 11         276           146           0                    0         299
# ...

# %%
mean = numeric.mean()
mean
# Out:
# bap_tilang             170.333333
# stop_operasi            62.690476
# bap_polisi               5.761905
# stop_operasi_polisi      0.000000
# penderekan             160.285714
# ocp_roda_dua           103.428571
# ocp_roda_empat          13.809524
# angkut_motor            26.000000
# dtype: float64

# %%
median = numeric.median()
median
# Out:
# bap_tilang             164.0
# stop_operasi            46.5
# bap_polisi               0.0
# stop_operasi_polisi      0.0
# penderekan             157.0
# ocp_roda_dua             5.0
# ocp_roda_empat           1.0
# angkut_motor             0.0
# dtype: float64

# %%
#No. 4
# q1 = np.percentile(numeric['bap_tilang'], 25)
# q2 = np.percentile(numeric['bap_tilang'], 50)
# q3 = np.percentile(numeric['bap_tilang'], 75)

# print('q1 bap tilang = ', q1)
# print('q2 bap tilang = ', q2)
# print('q3 bap tilang = ', q3)
# print('')

# q1 = np.percentile(numeric['stop_operasi'], 25)
# q2 = np.percentile(numeric['stop_operasi'], 50)
# q3 = np.percentile(numeric['stop_operasi'], 75)

# print('q1 stop operasi = ', q1)
# print('q2 stop operasi = ', q2)
# print('q3 stop operasi = ', q3)
# print('')

q1 = np.percentile(numeric, 25, axis =0)
q2 = np.percentile(numeric, 50, axis =0)
q3 = np.percentile(numeric, 75, axis =0)

print(q1)
print(q2)
print(q3)
# Out:
# [69.   20.25  0.    0.   98.    0.    0.    0.  ]
# [164.   46.5   0.    0.  157.    5.    1.    0. ]
# [246.5  105.5    0.     0.   205.25 156.5    7.5    0.  ]

# %%
group = lalin[['bulan', 'bap_tilang']]
group
# Out:
#        bulan  bap_tilang
# 0    Januari          44
# 1    Januari          47
# 2    Januari         166
# 3    Januari          44
# 4    Januari         184
# 5    Januari         191
# 6   Februari          37
# 7   Februari          48
# 8   Februari         251
# 9   Februari         129
# 10  Februari         229
# 11  Februari         276
# 12     Maret          90
# 13     Maret          68
# 14     Maret         323
# 15     Maret         479
# 16     Maret         270
# 17     Maret         253
# 18     April          78
# 19     April          93
# 20     April         293
# 21     April         454
# 22     April         233
# 23     April         274
# 24       Mei          47
# 25       Mei          30
# 26       Mei         174
# 27       Mei         203
# 28       Mei         156
# 29       Mei         162
# 30      Juni         113
# 31      Juni          24
# 32      Juni         365
# 33      Juni         390
# 34      Juni         176
# 35      Juni         217
# ...

# %%
#No. 5


hasil = lalin.groupby('bulan')['bap_tilang'].mean()
hasil
# Out:
# bulan
# April       237.500000
# Februari    161.666667
# Januari     112.666667
# Juli         90.500000
# Juni        214.166667
# Maret       247.166667
# Mei         128.666667
# Name: bap_tilang, dtype: float64

# %%
data = [8,6,6,5,9,9,3,4,4,2,10]
mean = np.mean(data)
mean
# Out:
# 6.0
