# %%
import numpy as np
import pandas as pd
import io

url = ('https://raw.githubusercontent.com/gemara/data_analyst/main/bali_tourist.csv')
turis = pd.read_csv(url)
turis
# Out:
#      year                 area               country  January  February  \
# 0    2019        ASIA PACIFIC             AUSTRALIAN    95536     67474
# 1    2019        ASIA PACIFIC                 BHUTAN       60        30
# 2    2019        ASIA PACIFIC             BANGLADESH     2262      2094
# 3    2019        ASIA PACIFIC                   FIJI       91        73
# 4    2019        ASIA PACIFIC               HONGKONG     1313      1367
# ..    ...                  ...                   ...      ...       ...
# 357  2018          MIDDLE EAST                TURKEY      899       615
# 358  2018          MIDDLE EAST  UNITED ARAB EMIRATES      170       132
# 359  2018          MIDDLE EAST                 YAMAN       98        49
# 360  2018          MIDDLE EAST                JORDAN      225       153
# 361  2018  OTHER NATIONALITIES   OTHER NATIONALITIES     6952      1704
#
#      March    April    May    June    July  August  September  October  \
# ...

# %%
from pandas.core.groupby.groupby import T
#Tugas No. 1

d2018 = turis[turis['year'] == 2018]
d2019 = turis[turis['year'] == 2019]

bulan = ['January','February','March','April','May','June','July','August','September','October','November','December']

t2018 = d2018[bulan].sum()
t2019 = d2019[bulan].sum()

k2018 = t2018.sum()
k2019 = t2019.sum()

print(f"total jumlah turis 2018 = ", k2018)
print(f"total jumlah turis 2019 = ", k2019)
# Out:
# total jumlah turis 2018 =  6073353.0
# total jumlah turis 2019 =  6275045.0

# %%
#Tugas No. 2
mean_k2018 = k2018.mean()
mean_k2019 = k2019.mean()

print(f'rata-rata pengunjung tahung 2018 = ',round(mean_k2018))
print(f'rata-rata pengunjung tahung 2019 = ',round(mean_k2019))
# Out:
# rata-rata pengunjung tahung 2018 =  6073353
# rata-rata pengunjung tahung 2019 =  6275045

# %%
#Tugas No. 3

ma2018 = t2018.idxmax()
ma2019 = t2019.idxmax()
mi2018 = t2018.idxmin()
mi2019 = t2019.idxmin()

print(f'jumlah turis 2018 paling banyak pada bulan : ',ma2018)
print(f'jumlah turis 2019 paling banyak pada bulan : ',ma2019)
# Out:
# jumlah turis 2018 paling banyak pada bulan :  July
# jumlah turis 2019 paling banyak pada bulan :  August

# %%
#Tugas No. 4

print(f'jumlah turis 2018 paling sedikit pada bulan : ',mi2018)
print(f'jumlah turis 2019 paling sedikit pada bulan : ',mi2019)
# Out:
# jumlah turis 2018 paling sedikit pada bulan :  January
# jumlah turis 2019 paling sedikit pada bulan :  February

# %%
#Tugas No. 5

g2018 = d2018.groupby('area')[bulan].sum()

g2018.idxmax()

g2019 = d2019.groupby('area')[bulan].sum()

g2019.idxmax()
# Out:
# January      ASIA PACIFIC
# February     ASIA PACIFIC
# March        ASIA PACIFIC
# April        ASIA PACIFIC
# May          ASIA PACIFIC
# June         ASIA PACIFIC
# July         ASIA PACIFIC
# August       ASIA PACIFIC
# September    ASIA PACIFIC
# October      ASIA PACIFIC
# November     ASIA PACIFIC
# December     ASIA PACIFIC
# dtype: object

# %%
#Tugas Tabel
tabel1 = d2018.groupby('year')[bulan].sum()
tabel2 = d2019.groupby('year')[bulan].sum()

tabel1['Max'] = ma2018
tabel1['Min'] = mi2018
tabel1['kedatangan setahun'] = round(k2018)
tabel1['rata-rata'] = round(mean_k2018)

tabel2['Max'] = ma2019
tabel2['Min'] = mi2019
tabel2['kedatangan setahun'] = round(k2019)
tabel2['rata-rata'] = round(mean_k2019)

final_tabel = pd.concat([tabel1, tabel2])

final_tabel
# Out:
#       January  February   March     April     May    June    July  August  \
# year
# 2018   358065    452423  492678  516777.0  528512  544550  624366  573766
# 2019   456218    437537  449637  476327.0  485634  549751  594279  616706
#
#       September  October  November  December     Max       Min  \
# year
# 2018     555903   517889    407213    501211    July   January
# 2019     590565   568064    497925    552402  August  February
#
#       kedatangan setahun  rata-rata
# year
# 2018             6073353    6073353
# 2019             6275045    6275045
