# %%
import os
import copy
import getpass
from IPython.display import clear_output

user1 = "babangkendang"
user2 = "admin"
pass1 = "1234"
pass2 = "pass"
users = {user1,user2}
proses_admin = {1,2,3,4,5}
proses_admin2 = proses_admin
proses_user = (1,2,3)

buah = {
    1 : "apel",
    2 : "jeruk",
    3 : "pisang",
    4 : "mangga",
    5 : "pepaya"
}
sayur = {
    1 : "terong",
    2 : "timun",
    3 : "kol",
    4 : "wortel",
    5 : "brokoli"
}
daging = {
    1 : "ayam",
    2 : "sapi",
    3 : "babi",
    4 : "kambing",
    5 : "ikan"
}
obat = {
    1 : "batuk",
    2 : "flu",
    3 : "tolak angin",
    4 : "minyak kayu putih",
    5 : "vitamin c"
}
def proses_pilih_angka():
  global num_admin1
  try:
    num_admin1 = int(input("Pilihan = "))
  except ValueError:
    print("")
    print("Harus berupa angka!")
  except TypeError:
    print("")
    print("Harus berupa angka!")
  except ZeroDivisionError:
    print("")
    print("angka tidak boleh nol")
  finally:
    print("")

def lanjut_admin():
  global num_admin1
  print("")
  print("1. Tampil Barang")
  print("2. Tambah Barang")
  print("3. Hapus Barang")
  print("4. Ubah Barang")
  print("5. Selesai")
  print("")
  proses_pilih_angka()
  if num_admin1 not in proses_admin:
    clear_output()
    print("")
    print("Pilihan Tidak Tersedia, Silahkan Coba Lagi!")
    lanjut_admin()
  elif num_admin1 == 1:
    print("1. Buah")
    print("2. Sayur")
    print("3. Daging")
    print("4. Obat")
    print("5. Semua")
    proses_pilih_angka()
    if num_admin1 not in proses_admin2:
      clear_output()
      print("Pilihan Tidak Tersedia, Silahkan Coba Lagi!")
      proses_pilih_angka()
    elif num_admin1 == 1:
      clear_output()
      print(buah)
      lanjut_admin()
    elif num_admin1 == 2:
      clear_output()
      print(sayur)
      lanjut_admin()
    elif num_admin1 == 3:
      clear_output()
      print(daging)
      lanjut_admin()
    elif num_admin1 == 4:
      clear_output()
      print(obat)
      lanjut_admin()
    elif num_admin1 == 5:
      clear_output()
      print(buah)
      print(sayur)
      print(daging)
      print(obat)
      lanjut_admin()
  elif num_admin1 == 5:
    print("proses telah selesai, silahkan login kembali!")



def lanjut_user():
  clear_output()
  print("")
  print("1. Tampil Barang")
  print("2. Beli Barang")
  try:
    num_user1 = int(input("Pilihan = "))
  except ValueError:
    print("")
    print("Harus berupa angka!")
  except TypeError:
    print("")
    print("Harus berupa angka!")
  except ZeroDivisionError:
    print("")
    print("angka tidak boleh nol")
  finally:
    print("")
    print("proses selesai")

def ulangi_admin():
  clear_output()
  lanjut_admin()

while True:
  clear_output()
  print("")
  print("Silahkan Masukkan Username Anda!")
  print("")

  try:
    username = (str(input("username = ")))
  finally:

    if username not in users:
      print("")
      print("username salah, silahkan coba lagi!")
      print("")

    elif username == user1:
      print("")
      print("password :")
      password = getpass.getpass()
      print("")
      if password == pass1:
        clear_output()
        lanjut_user()
      else:
        clear_output()
        print("")
        print("Password Salah! Silahkan Ulangi Dari Awal!")
        print("")
    elif username == user2:
      print("")
      print("password :")
      password = getpass.getpass()
      print("")
      if password == pass2:
        clear_output()
        lanjut_admin()
      else:
        clear_output()
        print("")
        print("Password Salah! Silahkan Ulangi Dari Awal!")
        print("")
# Out:
# {1: 'terong', 2: 'timun', 3: 'kol', 4: 'wortel', 5: 'brokoli'}
#
# 1. Tampil Barang
# 2. Tambah Barang
# 3. Hapus Barang
# 4. Ubah Barang
# 5. Selesai
