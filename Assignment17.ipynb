# %%
#data frame

import pandas as pd
import numpy as np

data_frame = pd.DataFrame([
    [1,2,3],
    [4,5,6]
], index = ['satu','dua'], columns = ['kolom1','kolom2','kolom3'])

data_frame
# Out:
#       kolom1  kolom2  kolom3
# satu       1       2       3
# dua        4       5       6

# %%
data_frame.index = ['a','b']

data_frame
# Out:
#    kolom1  kolom2  kolom3
# a       1       2       3
# b       4       5       6

# %%
data_frame.columns = ['column 1','column 2','column 3']

data_frame
# Out:
#    column 1  column 2  column 3
# a         1         2         3
# b         4         5         6

# %%
data_frame.columns
# Out:
# Index(['column 1', 'column 2', 'column 3'], dtype='object')

# %%
data_frame[["column 1","column 2"]]
# Out:
#    column 1  column 2
# a         1         2
# b         4         5

# %%
data_frame.loc["a":,["column 3","column 2"]]
# Out:
#    column 3  column 2
# a         3         2
# b         6         5

# %%
data_frame.iloc[0:, [1, 2]]
# Out:
#    column 2  column 3
# a         2         3
# b         5         6

# %%
data_f = pd.DataFrame({
    "nama" : ['adam','enoch','noah','seth'],
    "umur" : [900,800,700,600]
})
data_f
# Out:
#     nama  umur
# 0   adam   900
# 1  enoch   800
# 2   noah   700
# 3   seth   600

# %%
#Tugas No. 1

data_tugasdf = pd.DataFrame({
    'Athlete':['Michael Phelp','Michael Phelp','Michael Phelp','Natalie Coughlin','Aleksey Nemov'],
    'Age':[23,19,27,25,24],
    'Country' :['United States','Canada','United States','Norway','China'],
    'Year':[2008,2004,2012,2008,2000],
    'Gold Medals':[8,6,4,1,4]
}, columns=['Athlete','Age','Country','Year','Gold Medals'])
data_tugasdf
# Out:
#             Athlete  Age        Country  Year  Gold Medals
# 0     Michael Phelp   23  United States  2008            8
# 1     Michael Phelp   19         Canada  2004            6
# 2     Michael Phelp   27  United States  2012            4
# 3  Natalie Coughlin   25         Norway  2008            1
# 4     Aleksey Nemov   24          China  2000            4

# %%
#Tugas No. 2
data_tugasdf.columns
# Out:
# Index(['Athlete', 'Age', 'Country', 'Year', 'Gold Medals'], dtype='object')

# %%
#Tugas No. 3 Manual
data_tugasdf.loc[0:, ['Athlete','Country','Year']]
# Out:
#             Athlete        Country  Year
# 0     Michael Phelp  United States  2008
# 1     Michael Phelp         Canada  2004
# 2     Michael Phelp  United States  2012
# 3  Natalie Coughlin         Norway  2008
# 4     Aleksey Nemov          China  2000

# %%
#Tugas No. 3 Auto
masukan = input("masukkan data : ").split()
data_tugasdf[masukan]
# Out:
# masukkan data : Athlete Country Year
#             Athlete        Country  Year
# 0     Michael Phelp  United States  2008
# 1     Michael Phelp         Canada  2004
# 2     Michael Phelp  United States  2012
# 3  Natalie Coughlin         Norway  2008
# 4     Aleksey Nemov          China  2000

# %%
#Tugas No. 4
data_tugasdf[0:3]
# Out:
#          Athlete  Age        Country  Year  Gold Medals
# 0  Michael Phelp   23  United States  2008            8
# 1  Michael Phelp   19         Canada  2004            6
# 2  Michael Phelp   27  United States  2012            4
