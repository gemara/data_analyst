# %%
import io
import pandas as pd
import numpy as np

url = ("https://raw.githubusercontent.com/gemara/data_analyst/main/package_tourism.csv")
tour = pd.read_csv(url)
tour
# Out:
#     Package      City                   Place_Tourism1  \
# 0         1   Jakarta                Pasar Tanah Abang
# 1         2   Jakarta                Pasar Tanah Abang
# 2         3   Jakarta            Perpustakaan Nasional
# 3         4   Jakarta                     Pulau Tidung
# 4         5   Jakarta            Museum Satria Mandala
# ..      ...       ...                              ...
# 95       96  Surabaya      Ekowisata Mangrove Wonorejo
# 96       97  Surabaya                Ciputra Waterpark
# 97       98  Surabaya    Museum Kesehatan Dr. Adhyatma
# 98       99  Surabaya  Taman Ekspresi Dan Perpustakaan
# 99      100  Surabaya              Taman Buah Surabaya
#
#               Place_Tourism2                  Place_Tourism3  \
# 0               Taman Ayodya                  Museum Tekstil
# 1         Pasar Taman Puring            Pasar Petak Sembilan
# 2                      Monas                 Masjid Istiqlal
# ...

# %%
# Tugas No. 1
tour.columns = ['Paket', 'Kota', 'Destinasi1', 'Destinasi2', 'Destinasi3',
       'Destinasi4', 'Destinasi5']
tour
# Out:
#     Paket      Kota                       Destinasi1  \
# 0       1   Jakarta                Pasar Tanah Abang
# 1       2   Jakarta                Pasar Tanah Abang
# 2       3   Jakarta            Perpustakaan Nasional
# 3       4   Jakarta                     Pulau Tidung
# 4       5   Jakarta            Museum Satria Mandala
# ..    ...       ...                              ...
# 95     96  Surabaya      Ekowisata Mangrove Wonorejo
# 96     97  Surabaya                Ciputra Waterpark
# 97     98  Surabaya    Museum Kesehatan Dr. Adhyatma
# 98     99  Surabaya  Taman Ekspresi Dan Perpustakaan
# 99    100  Surabaya              Taman Buah Surabaya
#
#                   Destinasi2                      Destinasi3  \
# 0               Taman Ayodya                  Museum Tekstil
# 1         Pasar Taman Puring            Pasar Petak Sembilan
# 2                      Monas                 Masjid Istiqlal
# 3             Pulau Bidadari                      Pulau Pari
# ...

# %%
tour.shape
# Out:
# (100, 7)

# %%
tour.head(10)
# Out:
#    Paket     Kota                          Destinasi1  \
# 0      1  Jakarta                   Pasar Tanah Abang
# 1      2  Jakarta                   Pasar Tanah Abang
# 2      3  Jakarta               Perpustakaan Nasional
# 3      4  Jakarta                        Pulau Tidung
# 4      5  Jakarta               Museum Satria Mandala
# 5      6  Jakarta  Waterboom PIK (Pantai Indah Kapuk)
# 6      7  Jakarta                  Alive Museum Ancol
# 7      8  Jakarta                            Kota Tua
# 8      9  Jakarta           Galeri Nasional Indonesia
# 9     10  Jakarta             Taman Impian Jaya Ancol
#
#                     Destinasi2             Destinasi3  \
# 0                 Taman Ayodya         Museum Tekstil
# 1           Pasar Taman Puring   Pasar Petak Sembilan
# 2                        Monas        Masjid Istiqlal
# 3               Pulau Bidadari             Pulau Pari
# 4                Museum Wayang  Museum Bahari Jakarta
# ...

# %%
tour.tail(10)
# Out:
#     Paket      Kota                       Destinasi1  \
# 90     91  Surabaya      Ekowisata Mangrove Wonorejo
# 91     92  Surabaya              Taman Kunang-Kunang
# 92     93  Surabaya    Museum TNI AL Loka Jala Crana
# 93     94  Surabaya              Taman Buah Surabaya
# 94     95  Surabaya    Museum TNI AL Loka Jala Crana
# 95     96  Surabaya      Ekowisata Mangrove Wonorejo
# 96     97  Surabaya                Ciputra Waterpark
# 97     98  Surabaya    Museum Kesehatan Dr. Adhyatma
# 98     99  Surabaya  Taman Ekspresi Dan Perpustakaan
# 99    100  Surabaya              Taman Buah Surabaya
#
#                          Destinasi2                             Destinasi3  \
# 90            Taman Harmoni Keputih       Taman Air Mancur Menari Kenjeran
# 91  Taman Ekspresi Dan Perpustakaan       Taman Air Mancur Menari Kenjeran
# 92           Klenteng Sanggar Agung  Museum Sepuluh Nopember Kota Surabaya
# 93                    Taman Pelangi                    Hutan Bambu Keputih
# ...

# %%
url2 = ("https://raw.githubusercontent.com/mediatechid/bootcamp-data-analyst/main/zomato_resto_file1.json")
zomato = pd.read_json(url2)
zomato
# Out:
#      results_found                                        restaurants  \
# 0          17151.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# 1           4748.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 2          13786.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 3          10224.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 4           7039.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# ..             ...                                                ...
# 474            NaN                                                NaN
# 475            NaN                                                NaN
# 476            NaN                                                NaN
# 477            NaN                                                NaN
# 478            NaN                                                NaN
#
#      results_shown  results_start             message   code status
# ...

# %%
zomato.shape
# Out:
# (479, 7)

# %%
zomato.head(10)
# Out:
#    results_found                                        restaurants  \
# 0        17151.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# 1         4748.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 2        13786.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 3        10224.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 4         7039.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 5         5678.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 6         5374.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 7         1382.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 8         1534.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# 9         2206.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
#
#    results_shown  results_start message  code status
# 0           20.0            1.0     NaN   NaN    NaN
# 1           20.0            1.0     NaN   NaN    NaN
# 2           20.0            1.0     NaN   NaN    NaN
# ...

# %%
zomato.tail(10)
# Out:
#      results_found restaurants  results_shown  results_start  \
# 469            NaN         NaN            NaN            NaN
# 470            NaN         NaN            NaN            NaN
# 471            NaN         NaN            NaN            NaN
# 472            NaN         NaN            NaN            NaN
# 473            NaN         NaN            NaN            NaN
# 474            NaN         NaN            NaN            NaN
# 475            NaN         NaN            NaN            NaN
# 476            NaN         NaN            NaN            NaN
# 477            NaN         NaN            NaN            NaN
# 478            NaN         NaN            NaN            NaN
#
#                 message   code status
# 469  API limit exceeded  440.0
# 470  API limit exceeded  440.0
# 471  API limit exceeded  440.0
# 472  API limit exceeded  440.0
# 473  API limit exceeded  440.0
# 474  API limit exceeded  440.0
# 475  API limit exceeded  440.0
# ...

# %%
zomato["restaurants"]
# Out:
# 0      [{'restaurant': {'has_online_delivery': 1, 'ph...
# 1      [{'restaurant': {'has_online_delivery': 0, 'ph...
# 2      [{'restaurant': {'has_online_delivery': 0, 'ph...
# 3      [{'restaurant': {'has_online_delivery': 0, 'ph...
# 4      [{'restaurant': {'has_online_delivery': 0, 'ph...
#                              ...
# 474                                                  NaN
# 475                                                  NaN
# 476                                                  NaN
# 477                                                  NaN
# 478                                                  NaN
# Name: restaurants, Length: 479, dtype: object

# %%
for names in zomato["restaurants"]:
  for name in names:
    print(name["restaurant"]["name"])
# Out:
# Hauz Khas Social
# Qubitos - The Terrace Cafe
# The Hudson Cafe
# Summer House Cafe
# 38 Barracks
# Spezia Bistro
# Manhattan Brewery & Bar Exchange
# The Wine Company
# Farzi Cafe
# Indian Grill Room
# Cafeteria & Co.
# Farzi Cafe
# Molecule Air Bar
# HotMess
# My Bar Headquarters
# FLYP@MTV
# Tamasha
# The Barbeque Company
# Saravana Bhavan
# Odeon Social
# Spice Kraft
# Hoppipola
# Barbeque Nation
# Peter Cat
# Barbeque Nation
# What's Up
# 6 Ballygunge Place
# TGI Friday's
# The Irish House
# Asia Kitchen by Mainland China
# India Restaurant
# Nawwarah
# Santa's Fantasea
# Mumbai Local
# Sigree Global Grill
# BarBQ
# Mocambo
# Gabbar's Bar & Kitchen
# Ocean Grill
# Flame & Grill
# Farzi Cafe
# The Fusion Kitchen
# Tea Villa Cafe
# Mumbai Vibe
# 38 Degree East
# Mirchi And Mime
# R' ADDA
# The American Joint
# Grandmama's Cafe
# SpiceKlub
# Stacks And Racks
# Tea Villa Cafe
# Cafe Hydro
# Tea Villa Cafe
# Joey's Pizza
# Joey's Pizza
# The Rolling Pin
# Tea Villa Cafe
# ...
