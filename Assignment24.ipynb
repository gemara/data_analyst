# %%
import pandas as pd
import numpy as np
import io

url = ('https://raw.githubusercontent.com/gemara/data_analyst/main/penyakit_ginjal_kronik-1.csv')
ginjal = pd.read_csv(url)
ginjal_data = pd.read_csv(url)
ginjal
# Out:
#       id  umur  tekanandarah  gravitas  albumin  sugar seldarahmerah  \
# 0      0  48.0          80.0     1.020      1.0    0.0           NaN
# 1      1   7.0          50.0     1.020      4.0    0.0           NaN
# 2      2  62.0          80.0     1.010      2.0    3.0  Tidak Normal
# 3      3  48.0          70.0     1.005      4.0    0.0  Tidak Normal
# 4      4  51.0          80.0     1.010      2.0    0.0  Tidak Normal
# ..   ...   ...           ...       ...      ...    ...           ...
# 395  395  55.0          80.0     1.020      0.0    0.0  Tidak Normal
# 396  396  42.0          70.0     1.025      0.0    0.0  Tidak Normal
# 397  397  12.0          80.0     1.020      0.0    0.0  Tidak Normal
# 398  398  17.0          60.0     1.025      0.0    0.0  Tidak Normal
# 399  399  58.0          80.0     1.025      0.0    0.0  Tidak Normal
#
#            pussel    gds  ureum  ...  MCV  seldarahputih  seldarahmerah.1  \
# ...

# %%
#Tugas No. 1
ginjal.isnull().sum()
# Out:
# id                   0
# umur                 9
# tekanandarah        12
# gravitas            47
# albumin             46
# sugar               49
# seldarahmerah      152
# pussel              65
# gds                 44
# ureum               19
# kreatinin           17
# natrium             87
# kalium              88
# hemoglobin          52
# MCV                 70
# seldarahputih      105
# seldarahmerah.1    130
# hipertensi           2
# diabetes             2
# cad                  2
# nafsumakan           1
# edema                1
# anemia               1
# klasifikasi          0
# dtype: int64

# %%
#Tugas No. 2
ginjal2 = ginjal_data.dropna()
ginjal2
# Out:
#       id  umur  tekanandarah  gravitas  albumin  sugar seldarahmerah  \
# 3      3  48.0          70.0     1.005      4.0    0.0  Tidak Normal
# 9      9  53.0          90.0     1.020      2.0    0.0        Normal
# 11    11  63.0          70.0     1.010      3.0    0.0        Normal
# 14    14  68.0          80.0     1.010      3.0    2.0  Tidak Normal
# 20    20  61.0          80.0     1.015      2.0    0.0        Normal
# ..   ...   ...           ...       ...      ...    ...           ...
# 395  395  55.0          80.0     1.020      0.0    0.0  Tidak Normal
# 396  396  42.0          70.0     1.025      0.0    0.0  Tidak Normal
# 397  397  12.0          80.0     1.020      0.0    0.0  Tidak Normal
# 398  398  17.0          60.0     1.025      0.0    0.0  Tidak Normal
# 399  399  58.0          80.0     1.025      0.0    0.0  Tidak Normal
#
#            pussel    gds  ureum  ...  MCV  seldarahputih  seldarahmerah.1  \
# ...

# %%
#Tugas No. 3
# ginjal3 = ginjal2[['hipertensi','diabetes']].replace('yes', 'iya')
# ginjal4 = ginjal2.drop(['hipertensi','diabetes'], axis = 1)
# for hipertensi, col_data in df_new.items():
#     df.insert(position, col_name, col_data)
ginjal4[['diabetes','hipertensi']] = ginjal3[['diabetes','hipertensi']].replace('yes','iya')
ginjal4
# Out:
#       id  umur  tekanandarah  gravitas  albumin  sugar seldarahmerah  \
# 3      3  48.0          70.0     1.005      4.0    0.0  Tidak Normal
# 9      9  53.0          90.0     1.020      2.0    0.0        Normal
# 11    11  63.0          70.0     1.010      3.0    0.0        Normal
# 14    14  68.0          80.0     1.010      3.0    2.0  Tidak Normal
# 20    20  61.0          80.0     1.015      2.0    0.0        Normal
# ..   ...   ...           ...       ...      ...    ...           ...
# 395  395  55.0          80.0     1.020      0.0    0.0  Tidak Normal
# 396  396  42.0          70.0     1.025      0.0    0.0  Tidak Normal
# 397  397  12.0          80.0     1.020      0.0    0.0  Tidak Normal
# 398  398  17.0          60.0     1.025      0.0    0.0  Tidak Normal
# 399  399  58.0          80.0     1.025      0.0    0.0  Tidak Normal
#
#            pussel    gds  ureum  ...  MCV  seldarahputih  seldarahmerah.1  \
# ...

# %%
#Tugas No. 4
print('SEBELUM PENGHAPUSAN :')
print('')
ginjal
# Out:
# SEBELUM PENGHAPUSAN :
#       id  umur  tekanandarah  gravitas  albumin  sugar seldarahmerah  \
# 0      0  48.0          80.0     1.020      1.0    0.0           NaN
# 1      1   7.0          50.0     1.020      4.0    0.0           NaN
# 2      2  62.0          80.0     1.010      2.0    3.0  Tidak Normal
# 3      3  48.0          70.0     1.005      4.0    0.0  Tidak Normal
# 4      4  51.0          80.0     1.010      2.0    0.0  Tidak Normal
# ..   ...   ...           ...       ...      ...    ...           ...
# 395  395  55.0          80.0     1.020      0.0    0.0  Tidak Normal
# 396  396  42.0          70.0     1.025      0.0    0.0  Tidak Normal
# 397  397  12.0          80.0     1.020      0.0    0.0  Tidak Normal
# 398  398  17.0          60.0     1.025      0.0    0.0  Tidak Normal
# 399  399  58.0          80.0     1.025      0.0    0.0  Tidak Normal
#
#            pussel    gds  ureum  ...  MCV  seldarahputih  seldarahmerah.1  \
# ...

# %%
print('SESUDAH PENGHAPUSAN :')
print('')
ginjal2
# Out:
# SESUDAH PENGHAPUSAN :
#       id  umur  tekanandarah  gravitas  albumin  sugar seldarahmerah  \
# 3      3  48.0          70.0     1.005      4.0    0.0  Tidak Normal
# 9      9  53.0          90.0     1.020      2.0    0.0        Normal
# 11    11  63.0          70.0     1.010      3.0    0.0        Normal
# 14    14  68.0          80.0     1.010      3.0    2.0  Tidak Normal
# 20    20  61.0          80.0     1.015      2.0    0.0        Normal
# ..   ...   ...           ...       ...      ...    ...           ...
# 395  395  55.0          80.0     1.020      0.0    0.0  Tidak Normal
# 396  396  42.0          70.0     1.025      0.0    0.0  Tidak Normal
# 397  397  12.0          80.0     1.020      0.0    0.0  Tidak Normal
# 398  398  17.0          60.0     1.025      0.0    0.0  Tidak Normal
# 399  399  58.0          80.0     1.025      0.0    0.0  Tidak Normal
#
#            pussel    gds  ureum  ...  MCV  seldarahputih  seldarahmerah.1  \
# ...
