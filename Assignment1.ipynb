# %%
#Tugas No.1
musim = "Musim Panas"
print(musim)

#Tugas No.2
sum_math = (3+4+5)
hard_math = (3+4+5)
print(sum_math, hard_math)

#Tugas No.3
number_str = "08123123123"
print(number_str)

#Tugas No.4
contoh_str = "Halo, Saya sedang mengerjakan assignment"
contoh_int = (888)
contoh_float = (8,88)
contoh_boolean1 = True
contoh_boolean2 = 0
contoh_char = "F"
print(contoh_str)
print(contoh_int)
print(contoh_float)
print(contoh_boolean1)
print(contoh_boolean2)
print(contoh_char)

#Tugas No.5
angka_int = (45)
angka_float = (0.667)
angka_int2 = (12)
angka_int3 = (119)
konversi_int_float = float(angka_int)
konversi_float_int = int(angka_float)
konversi_int_hex = hex(angka_int2)
konversi_int_string = str(angka_int3)
print(konversi_int_float)
print(konversi_float_int)
print(konversi_int_hex)
print(konversi_int_string)
print(type(konversi_int_float))
print(type(konversi_float_int))
print(type(konversi_int_hex))
print(type(konversi_int_string))
# Out:
# Musim Panas
# 12 12
# 08123123123
# Halo, Saya sedang mengerjakan assignment
# 888
# (8, 88)
# True
# 0
# F
# 45.0
# 0
# 0xc
# 119
# <class 'float'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
