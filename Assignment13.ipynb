# %%
import copy
import numpy as np
from IPython.display import clear_output

print("Silahkan Masukkan 10 Angka untuk Diproses!")
print("")
a = int(input("Angka Pertama = "))
b = int(input("Angka Kedua = "))
c = int(input("Angka Ketiga = "))
d = int(input("Angka Keempat = "))
e = int(input("Angka Kelima = "))
f = int(input("Angka Keenam= "))
g = int(input("Angka Ketujuh = "))
h = int(input("Angka Kedelapan = "))
i = int(input("Angka Kesembilan = "))
j = int(input("Angka Kesepuluh = "))

data = {a,b,c,d,e,f,g,h,i,j}
panjang = len(data)

jumlah = sum(data)
print("")
print(f"Hasil penambahan kesepuluh angka tersebut adalah = ",jumlah)
print("")
rata_rata = ((sum(data))/panjang)
print(f"Hasil rata-rata dari kesepuluh angka tersebut adalah = ",rata_rata)
# Out:
# Silahkan Masukkan 10 Angka untuk Diproses!
#
# Angka Pertama = 24
# Angka Kedua = 25
# Angka Ketiga = 56
# Angka Keempat = 68
# Angka Kelima = 80
# Angka Keenam= 12
# Angka Ketujuh = 3
# Angka Kedelapan = 5
# Angka Kesembilan = 6
# Angka Kesepuluh = 77
# Hasil penambahan kesepuluh angka tersebut adalah =  356
# Hasil rata-rata dari kesepuluh angka tersebut adalah =  35.6
