# %%
import pandas as pd
import numpy as np
data = np.array(["Apple","Orange","Banana","Grape","Mango"])
series = pd.Series(data)
data_frame = pd.DataFrame(data)
print(series)
data_frame
# Out:
# 0     Apple
# 1    Orange
# 2    Banana
# 3     Grape
# 4     Mango
# dtype: object
#         0
# 0   Apple
# 1  Orange
# 2  Banana
# 3   Grape
# 4   Mango
